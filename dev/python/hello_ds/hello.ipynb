# %%
import pandas as pd
import numpy as np
data = pd.read_csv('titanic3.csv')

# %%
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %% [markdown]
# 替换？，将age和fare类型设置成float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr(numeric_only=True).abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr(numeric_only=True).abs()[["survived"]]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055512
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# body            NaN
# relatives  0.201719

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
# Out:
# ---------------------------------------------------------------------------
# SymbolAlreadyExposedError                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import Dense
#       4 model = Sequential()
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/__internal__/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/__internal__/backend/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.src.backend import _initialize_variables as initialize_variables
#       4 from keras.src.backend import track_variable
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/src/__init__.py:21
#       1 # Copyright 2015 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
# ---> 21 from keras.src import applications
#      22 from keras.src import distribute
#      23 from keras.src import models
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/src/applications/__init__.py:18
#       1 # Copyright 2016 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras Applications are premade architectures with pre-trained weights."""
# ---> 18 from keras.src.applications.convnext import ConvNeXtBase
#      19 from keras.src.applications.convnext import ConvNeXtLarge
#      20 from keras.src.applications.convnext import ConvNeXtSmall
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/src/applications/convnext.py:26
#      17 """ConvNeXt models for Keras.
#      18
#      19 References:
#    (...)
#      22   (CVPR 2022)
#      23 """
#      25 import numpy as np
# ---> 26 import tensorflow.compat.v2 as tf
#      28 from keras.src import backend
#      29 from keras.src import initializers
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/tensorflow/__init__.py:478
#     473 # Do an eager load for Keras' code so that any function/method that needs to
#     474 # happen at load time will trigger, eg registration of optimizers in the
#     475 # SavedModel registry.
#     476 # See b/196254385 for more details.
#     477 try:
# --> 478   importlib.import_module("keras.optimizers")
#     479 except (ImportError, AttributeError):
#     480   pass
#
# File /usr/lib/python3.8/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/optimizers/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.optimizers import experimental
#       4 from keras.optimizers import legacy
#       5 from keras.optimizers import schedules
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/optimizers/experimental/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.src.optimizers.adadelta import Adadelta
#       4 from keras.src.optimizers.adafactor import Adafactor
#       5 from keras.src.optimizers.adagrad import Adagrad
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/src/optimizers/__init__.py:28
#      25 import tensorflow.compat.v2 as tf
#      26 from absl import logging
# ---> 28 from keras.src import backend
#      29 from keras.src.optimizers import adadelta
#      30 from keras.src.optimizers import adafactor
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/src/backend.py:35
#      33 from keras.src.distribute import distribute_coordinator_utils as dc
#      34 from keras.src.dtensor import dtensor_api as dtensor
# ---> 35 from keras.src.engine import keras_tensor
#      36 from keras.src.utils import control_flow_util
#      37 from keras.src.utils import object_identity
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/src/engine/keras_tensor.py:19
#      15 """Keras Input Tensor used to track functional API Topology."""
#      17 import tensorflow.compat.v2 as tf
# ---> 19 from keras.src.utils import object_identity
#      21 # isort: off
#      22 from tensorflow.python.data.util import structure
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/src/utils/__init__.py:20
#      15 """Public Keras utilities."""
#      17 # isort: off
#      18
#      19 # Serialization related
# ---> 20 from keras.src.saving.serialization_lib import deserialize_keras_object
#      21 from keras.src.saving.serialization_lib import serialize_keras_object
#      22 from keras.src.saving.object_registration import CustomObjectScope
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/src/saving/serialization_lib.py:28
#      26 from keras.src.saving import object_registration
#      27 from keras.src.saving.legacy import serialization as legacy_serialization
# ---> 28 from keras.src.saving.legacy.saved_model.utils import in_tf_saved_model_scope
#      29 from keras.src.utils import generic_utils
#      31 # isort: off
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/src/saving/legacy/saved_model/utils.py:30
#      28 from keras.src.utils import tf_contextlib
#      29 from keras.src.utils.generic_utils import LazyLoader
# ---> 30 from keras.src.utils.layer_utils import CallFunctionSpec
#      32 training_lib = LazyLoader("training_lib", globals(), "keras.src.engine.training")
#      35 def use_wrapped_call(
#      36     layer, call_fn, call_spec, default_training_value=None, return_method=False
#      37 ):
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/src/utils/layer_utils.py:26
#      23 import numpy as np
#      24 import tensorflow.compat.v2 as tf
# ---> 26 from keras.src import initializers
#      27 from keras.src.utils import io_utils
#      29 # isort: off
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/src/initializers/__init__.py:23
#      20 import tensorflow.compat.v2 as tf
#      22 from keras.src.initializers import initializers
# ---> 23 from keras.src.initializers import initializers_v1
#      24 from keras.src.saving import serialization_lib
#      25 from keras.src.saving.legacy import serialization as legacy_serialization
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/keras/src/initializers/initializers_v1.py:32
#      29 _v1_glorot_uniform_initializer = tf.compat.v1.glorot_uniform_initializer
#      30 _v1_glorot_normal_initializer = tf.compat.v1.glorot_normal_initializer
# ---> 32 keras_export(v1=["keras.initializers.Zeros", "keras.initializers.zeros"])(
#      33     _v1_zeros_initializer
#      34 )
#      35 keras_export(v1=["keras.initializers.Ones", "keras.initializers.ones"])(
#      36     _v1_ones_initializer
#      37 )
#      38 keras_export(v1=["keras.initializers.Constant", "keras.initializers.constant"])(
#      39     _v1_constant_initializer
#      40 )
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/tensorflow/python/util/tf_export.py:348, in api_export.__call__(self, func)
#     345   delattr(undecorated_f, api_names_attr_v1)
#     347 _, undecorated_func = tf_decorator.unwrap(func)
# --> 348 self.set_attr(undecorated_func, api_names_attr, self._names)
#     349 self.set_attr(undecorated_func, api_names_attr_v1, self._names_v1)
#     351 for name in self._names:
#
# File ~/code/hhwe.github.io/.venv/lib/python3.8/site-packages/tensorflow/python/util/tf_export.py:364, in api_export.set_attr(self, func, api_names_attr, names)
#     362 if api_names_attr in func.__dict__:
#     363   if not self._allow_multiple_exports:
# --> 364     raise SymbolAlreadyExposedError(
#     365         'Symbol %s is already exposed as %s.' %
#     366         (func.__name__, getattr(func, api_names_attr)))  # pylint: disable=protected-access
#     367 setattr(func, api_names_attr, names)
#
# SymbolAlreadyExposedError: Symbol Zeros is already exposed as ().

# %%
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
#       2 model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
#       3 model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))
#
# AttributeError: 'GaussianNB' object has no attribute 'add'
